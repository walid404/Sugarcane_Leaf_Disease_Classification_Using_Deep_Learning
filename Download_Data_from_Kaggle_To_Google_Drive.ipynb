# %% [markdown]
# #Download Datasets From Kaggle To Google Drive

# %% [markdown]
# ## Step 1: Download Dataset API Token
#
#
#
# > We will download the Kaggle API token which will be present in Account directory under our Kaggle setting section. The file name for the token will be Kaggle.json

# %% [markdown]
# ![Screenshot-from-2023-05-10-16-06-18[1].png](data:image/png;base64,...)

# %% [markdown]
# ## Step 2: Upload API Token To Your Google Drive For Future Works

# %% [markdown]
# ## Step 3: Setup the Colab Notebook
#
#
# > To download the dataset into google colab notebook we first have to install kaggle in our local system then we will grant permission kaggle.json file to download file dataset from third party link

# %% [markdown]
# ### Install the Kaggle library

# %%
# !pip install kaggle

# %% [markdown]
# ## Make a directory named “.kaggle”

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %% [markdown]
# ### Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Copy the “kaggle.json” from Google Drive into this new directory

# %%
# !cp "/content/drive/MyDrive/Kaggle Token/kaggle.json" ~/.kaggle/

# %% [markdown]
# ## Allocate the required permission for this file.

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ##Step 4: Download the Dataset into Colab File
#
# > To download the dataset into Colab we will use another command followed by the dataset name
#
# > For Downloading dataset
# Suppose our dataset web link in
#
# >https://www.kaggle.com/datasets/nirmalsankalana/sugarcane-leaf-disease-dataset
#
# >then we will type

# %%
# !kaggle datasets download nirmalsankalana/sugarcane-leaf-disease-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nirmalsankalana/sugarcane-leaf-disease-dataset
# License(s): CC0-1.0
# ...
#  99% 158M/160M [00:02<00:00, 82.8MB/s]
# 100% 160M/160M [00:02<00:00, 71.0MB/s]

# %%
# !unzip /content/sugarcane-leaf-disease-dataset.zip
# Out:
# Archive:  /content/sugarcane-leaf-disease-dataset.zip
#   inflating: Healthy/healthy (1).jpeg
#   inflating: Healthy/healthy (10).jpeg
#   inflating: Healthy/healthy (100).jpeg
#   inflating: Healthy/healthy (101).jpeg
#   inflating: Healthy/healthy (102).jpeg
#   inflating: Healthy/healthy (103).jpeg
#   inflating: Healthy/healthy (104).jpeg
#   inflating: Healthy/healthy (105).jpeg
#   inflating: Healthy/healthy (106).jpeg
#   inflating: Healthy/healthy (107).jpeg
#   inflating: Healthy/healthy (108).jpeg
#   inflating: Healthy/healthy (109).jpeg
#   inflating: Healthy/healthy (11).jpeg
#   inflating: Healthy/healthy (110).jpeg
#   inflating: Healthy/healthy (111).jpeg
#   inflating: Healthy/healthy (112).jpeg
#   inflating: Healthy/healthy (113).jpeg
#   inflating: Healthy/healthy (114).jpeg
#   inflating: Healthy/healthy (115).jpeg
#   inflating: Healthy/healthy (116).jpeg
#   inflating: Healthy/healthy (117).jpeg
#   inflating: Healthy/healthy (118).jpeg
# ...

# %% [markdown]
# ### Make a directory to save the dataset in colab

# %%
# !mkdir "Sugarcane Leaf Disease Dataset"

# %% [markdown]
# ### Move data to directory

# %%
# !mv /content/Healthy "/content/Sugarcane Leaf Disease Dataset"
# !mv /content/Mosaic "/content/Sugarcane Leaf Disease Dataset"
# !mv /content/RedRot "/content/Sugarcane Leaf Disease Dataset"
# !mv /content/Rust "/content/Sugarcane Leaf Disease Dataset"
# !mv /content/Yellow "/content/Sugarcane Leaf Disease Dataset"

# %% [markdown]
# ### Make a directory in Google Drive to save data for future works

# %%
# !mkdir /content/drive/MyDrive/Datasets

# %% [markdown]
# ### Copy dataset to the directory

# %%
# !cp -r "/content/Sugarcane Leaf Disease Dataset" /content/drive/MyDrive/Datasets

# %% [markdown]
# # Now data in Google Drive and we are ready to work with it.

# %% [markdown]
# # References

# %% [markdown]
# #[GeeksforGeeks Website](https://www.geeksforgeeks.org/how-to-import-kaggle-datasets-directly-into-google-colab/)
